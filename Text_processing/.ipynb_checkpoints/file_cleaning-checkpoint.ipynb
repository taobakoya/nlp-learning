# %%
import pandas as pd

# %%
clndata = pd.read_csv("zomato_reviews.csv")

# %%
clndata
# Out:
#       Unnamed: 0  rating                                             review
# 0              0       5                                               nice
# 1              1       5  best biryani , so supportive staff of outlet ,...
# 2              2       4     delivery boy was very decent and supportive.👌👍
# 3              3       1  worst biryani i have tasted in my life, half o...
# 4              4       5  all food is good and tasty . will order again ...
# ...          ...     ...                                                ...
# 5474        5474       5                                           complain
# 5475        5475       5  it took 1 hour to assign valvet and thn prepar...
# 5476        5476       5  took for an hour to prepare 3 khawsa, which in...
# 5477        5477       1  very very late, littrally did time pass and it...
# 5478        5478       1  Taste was stale and they give only 5 pieces in...
#
# [5479 rows x 3 columns]

# %%
clndata['review'][3689]
# Out:
# nan

# %%
clndata = clndata.fillna(' ')

# %%
clndata.shape
# Out:
# (5479, 3)

# %% [markdown]
# <h3>Data Cleaning and processing</h3>

# %%
import re
import nltk
nltk.download('stopwords')

from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Tajudeen\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Tajudeen\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# ps = PorterStemmer()
wnl=WordNetLemmatizer()
corpus = []

for i in range(0, len(clndata)):
    review = re.sub('<.*>','',clndata['review'][i])
    review = re.sub('[^a-zA-Z]', ' ', clndata['review'][i])
    review = review.lower()
    review = review.split()
    
    # review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    #review = [wnl.lemmatize(word) for word in review if not word in stopwords.words('english')]
    
    review = ' '.join(review)
    corpus.append(review)

# %%
corpus
# Out:
# ['nice',
#  'best biryani so supportive staff of outlet personalize my order on call as i say full paisa vasool',
#  'delivery boy was very decent and supportive',
#  'worst biryani i have tasted in my life half of the biryani is in dustbin',
#  'all food is good and tasty will order again and lots more to explore in bawarchi s menu',
#  'shandar zabardast zindabad good going bawarchi keep it up',
#  'overall good experience will order again',
#  'good but cold of food',
#  'tasty food homestyle tasty prepration',
#  'loved it',
#  'full paisa vasool taste me best bawarchi aur everest',
#  'good taste authentic punjabi style matar paneer feels good to have such food in surat',
#  'very tasty authentic food',
#  'superb tasty asli dilli wala flavour',
#  'yummiest manchurian fried rice i have ever had in city authentic chinese taste must order once',
#  'veey tasty order again nd again',
#  'i have ordered manchurian fried rice but instead i got only simple fried rice feeling like i am cheated by bawarchi restaurant',
#  'very bad not properly cooked',
#  'delicious',
#  'chinese cheese kulcha good fusion of chinsese with punjabi cuisine accomplish with dal makhni and yummy butter milk must order',
#  'tasteis best zabardast mouthwatering must order again',
#  'taste less nd took min to deliver the order',
#  'i have tried a lot of dishes from bawarchi and choosing the best between them is a really tough task as all dishes are awesome',
#  'bawarchi satisfied there customer needs',
#  'too helping nature of resturent owners',
#  'i have tried many items from bawarchi these ppl never disappoint me keep it up',
#  'awesome experience guys these people really care about their customer satisfaction try and order i am sure u will love the taste',
#  'something good for cocktail party as the restaurant has mentioned good quantity was good too lage raho',
#  'superb taste really supreme thali in taste and quantity',
#  'free pizza was not given to me pizza hut does fraud till customer s condition is fulfilled',
#  'its good',
#  'free san francisco margarita pizza for orders above was not delivered though order was above',
#  'pizza base is not baked properly it s not crunchy then la pinos s pizza is baked properly',
#  'good experience',
#  'on time',
#  'very bad waste of money pizza hut no more like before very bad quality',
#  'pizza got cold waste of money',
#  'rotten pizza',
#  'had ordered a mushroom and corn pizza got only a corn one',
#  'mast',
#  'food is not hot',
#  'osm',
#  'no topping they have served only bread',
#  'pizza hut vari bad bro br all pablik pizzz not send pizz hat oder br vari vari bad test',
#  'i placed a complete different order and received complete different items not fair worst placements',
#  'so bad',
#  'their was a hair in my order horrible didn t expect this from pizza hut',
#  'worst pizza ever br no cheese no taste br just poured some liquid cheese which was pathetic n too salty',
#  'only cool pizza no socsh',
#  'corn pizza is missing in only vetted pizza out of',
#  'quality not much good and quantity are less',
#  'was not that good',
#  'nice',
#  'there is no ketchup',
#  'really horrible horrible i couldn t even eat',
#  'i can t receive the dip very bad',
#  'only chili flakes send by you and not provided origon masala with pizza and if possible please provide tomato sauce pauch with pizza',
#  'there were no ketchup how to eat dry pizza can t consume',
#  'good',
#  'the phone number was not working to edit the instructions',
#  'do complete care of the order and send to customer very properly outlet was not even having the oragano br very disappointing br moving out to eat something great as today s experience was hilarious and can t even trust more service of zomato',
#  'had given very very very very less chilli flakes and no oregano at all very dissapointed',
#  'please provide catch up also i am giving star because of taste',
#  'very bad experience',
#  'the order we rcd was very very cold and very very late',
#  'there was no oregano sachets',
#  'soft pizza bread enjoyed weekending',
#  'good test',
#  'it was nice but was not as good',
#  'dont buy pizza from pizza hut horrible pizza restuarant',
#  'very nice dilivery boy and nice work',
#  'the pizza was horrible the bread was stale could not eat the pizza stop making such bad pizzas',
#  'cheesy baked momos is very bad test and very tangy',
#  'quality food',
#  'packing was so dumb it was unsealed and so unhealthy and unhygienic',
#  'pizza hut is wrost never order it and after ordering it i got another order and even after that there is not any issue',
#  '',
#  'pepsi not available why',
#  'worst just wasted my money',
#  'everytime good experience this time it s was not good it s money waste',
#  'what is this br that s not even half a plate',
#  'kitna oily tha',
#  'great',
#  'great',
#  'not good not bad',
#  'nice',
#  'total careless restaurant not following order given by the customer please do not give further order for this restaurant',
#  'paav kio nhi bheja',
#  'no paper dish',
#  'noodles is very spicy can t to eat it and chilli paneer was small bad i don t have it',
#  'worst taste rice is burnt br after several calls restro didn t attended calls no reply br wouldn t recommend someone for this restro',
#  'excellent',
#  'nice man',
#  'please send full order then say how s taste',
#  'thank you for corporation',
#  'not good',
#  'very nice',
#  'mouth watering food',
#  'excellent food',
#  'delicious dish',
#  'very bad taste taste less saltless they don t even accept food instructions no cutlery and very costly',
#  'osum test',
#  'spoon nahi diya hai order k sath spoon dena cahiye',
#  'taste is very bad',
#  '',
#  'send cutlery in future for convenience outdoor eating',
#  'not fresh',
#  'awesome test',
#  'full tasty paw vaji',
#  'good taste good service thanks for accepting free soup',
#  'not yummy not test full br',
#  'machaow soup didn t send',
#  'nice',
#  'exilent',
#  'hhh',
#  'exlinat deliver boy',
#  'not satisfied with customer service',
#  'bad food',
#  'please follow customer s instructions properly i have asked to not to make anything spicy but you guys made it too spicy',
#  'perfect',
#  'supb',
#  'worthless',
#  'i have ordered grill cheese sandwich and there is no cheese',
#  'good fast best',
#  'i have received wrong parcel total fraud with me',
#  'horrible don t ruin your name by giving this types of food',
#  'bakavash',
#  'want to return it',
#  'i never expected they will send maked dosa br',
#  'delivery boy was very kind',
#  'very smelly pav bhaji',
#  'finger licking delicious as alwaysss',
#  'good',
#  'order delivery before time tks',
#  'bhai ishse ghatiya kuchh nahi khaya aaj tak',
#  'ok',
#  'not taeste',
#  'don t send cutlery',
#  'very good savis',
#  'please follow the customer s instructions properly',
#  'best peking on food',
#  'masala pav is not came in order so please next time take care for that',
#  'the mysore masala sabji was just so bad in taste it smells and tastes like shit',
#  'delicious food',
#  'good service',
#  'worst pulao ever',
#  'spoon not available',
#  'delivery boy good anf helpfull and very good beheviar i like her talking way and service',
#  'spoon nhi tha yahi hai buss br wrna or sab msttt',
#  'masala pav aaya hai nay tu kisa star do',
#  'food was spicy',
#  'late dilivery and food boht bakvas tha br never order from this restaurant',
#  'very bad food deleverd',
#  'after ravi has gone the taste is going bad to we are ravi s school friends so we know the taste which was before now it is really going worst',
#  'thanks great food love that you are take in account customer notes for food will order in future cheers',
#  'good',
#  'everything was good just a suggestion to please keep spoons and tissues as well',
#  'so late delivery',
#  'good',
#  'good',
#  'plz read instruction',
#  'bhaji need to supply in containers stop in plastic bag',
#  'it is like rubber hard to chew this is first time i am having a sandwich like this',
#  'they don t cancel order',
#  'yummy too good as usevl',
#  'i have ordered cold coffee and they delivered thik shake',
#  'bola tha fir bi only pc',
#  'superb',
#  'it s peanuts shake other flavours are far much better',
#  'size of both item is very less',
#  'your delivery is best but within km range rupees item turns rupees is too much',
#  'sugar',
#  'very nice',
#  'totally stale food',
#  'tasty',
#  'good',
#  'taste is so good',
#  '',
#  '',
#  'bad',
#  'osm delivery',
#  'good',
#  'not good quality not good test',
#  'very laziz',
#  'best service by the delivery boy',
#  'pizza packing amp test is desi coco excellent',
#  'good',
#  'okk',
#  'nice',
#  'super',
#  'no',
#  'good one',
#  'br',
#  'it was okay br beverage is not what i ordered and tastes really sweet',
#  'test good',
#  'not garam',
#  'br br',
#  'ordered with so much craze but highly disappointed',
#  'find',
#  'very fast delivery br br thanks zomato',
#  'good',
#  'delivery is too slow by zomato',
#  'i have ordered rajbhog thick shake with extra cashew thay not extra cashew and refuse to charge which i pay for extra cashew also zomato not help me very bad experience with mahalaxmi fast food and zomato i tell my all friends not to use zomato and not order to mahalaxmi fast food many other option we can',
#  'superb food best quality',
#  'give me my money back for which i have paid and item was missed in parcel in last order to gangour udhna',
#  'not good',
#  '',
#  'food was really nice there were no chillies we enjoyed it',
#  'good service',
#  'late delivery',
#  'i don t usually write reviews but i was compelled to write one due to the awesome tasting food with great packaging and on time delivery really happy with the quantity of food too highly recommended',
#  'bad behaviyar',
#  'sent less number of breads this time i will never give order again to gangor',
#  'very cold that and loss item',
#  'price is very extra',
#  'food was so yumm',
#  'too gud',
#  'hot and spice amazing',
#  'good',
#  'when u prepair n send the parcel to coustomer pls check wat r u sending',
#  'poor quality',
#  'i puked after having it',
#  'good',
#  'not bad',
#  'fantastic',
#  'test is best',
#  'good',
#  'not as expected',
#  'nice',
#  'always good',
#  'very bad delivery br i have mentioned not to ring bell br delivery boy has ring the bell which is very bad',
#  'exta kaju ka piya lekin rupey ke bheje makkhi chush',
#  'not happy with my order and your service',
#  'the deliver guy didn t knock and opened the door directly',
#  'taste and quality pehle jesa nhi',
#  'good',
#  'tast is better amp service is very satisfied',
#  'so small',
#  'thats diffrent from pic',
#  'fast delivery',
#  'many wested bismillah is rong br amul s chcho chips super many rs br party pack ml',
#  'too much sugar jjnnnnnnndnxbdhdbdbhdhfbhfhdhdhhdhdhh',
#  'superb',
#  'lots of cream instead of kaju anjeer kaju and anjeer thick shake taste was ok and bcz of pieces thick cream it was not giving proper taste br try to add more kaju and anjeer instead of cream',
#  'nice',
#  'good',
#  'osm quality',
#  'the delivery was made before time thanks',
#  'the delivery executive was fabulous',
#  'good',
#  'wow',
#  'delivery service very bad',
#  'supar sarve',
#  'this was my condition of parcel',
#  'nice',
#  'wow',
#  'quantity was less then appear in order so i dnt think so much to prefer bismillah',
#  'your thick shake was like a milk shake doesn t like it',
#  'nice',
#  'good job br br br br br br br br br br br br br br br br br br br br br br br br br br br br br br br br br br br br br br br br br br br',
#  'thx',
#  'received both items melted and sitafal was spoilt can t consumed zomato is not ready to take any responsibility for the same i believe they already know service of bismilah still they have allowed them to serve us worst desert totally waste of money big failure of zomato as well as restaurant',
#  'taste like hell too bad very bad not good quality',
#  'sab ghuli thi abhi kya kare ek dam bekar item nikla',
#  'not quality very late delivery not certified please service',
#  'not good seems to be plain vanilla ice cream with just a little amount of cookies more of just whipped cream',
#  'food quantity was lace cause of scheme schedule otherwise u can enjoy more quantity on live at shop',
#  'i m buying from bismillah only every time but this time taste is very bad they are giving old or expiry thick shake',
#  'bht bekar taste hai kabhi order ni krna paisa barbaad',
#  'want to talk with team asap',
#  'great',
#  'it s has test of garlic',
#  'the taste was soo good and spicy just how i like my food',
#  'teat saro hato br pan sandwich pochi thai gayi hati tena karane maza nai aavi',
#  'sandwich ka taste bhi accha nhi tha or baal nikle',
#  'good',
#  'taste was very bad br',
#  'only kobiz and tometo but not testy br and very hard bred br west mony',
#  'very nice',
#  'its awesome packing',
#  'taste not good half cooked',
#  'again like last time a new issu food item were totally tasteless',
#  'nice',
#  '',
#  'very test full and quentatiy item',
#  'better',
#  'very very very very nice food br',
#  'yaami',
#  'the food was totaly bad in taste fried rice to pura jal gya hua tha bekar tha br can t recommend to any one',
#  'good',
#  'osm test',
#  'food is very very bed chiter this shop br don t oder in this shope vest money',
#  'charging for cheese sandwich and where is the cheese fooling customer don t order',
#  'great',
#  'very low chesse like only vegetable plain sandwich restaurant take rate full and not give item quality',
#  'the restaurant service is not good and does not support',
#  'bed quality of chapati and all item',
#  'not good',
#  'not good food very bad taste',
#  'it was good only need to work on roties',
#  'not good',
#  'okok',
#  'good food',
#  'good',
#  'bed food',
#  'yaha se khana mat order kariye br total waste of money br itni gathiya quality ki chapati mene kabhi nahi dekh br kachha lot he aate ka br sabzi bhi puri ki puri dry he br kisi ko mar na he to yaha se sokh se khana mangvaye',
#  'very bad service roti delivered only pcs and out of rice full provide sabji less delivered packing not properly',
#  'chappatis are not properly baked i swear they are raw what the restaurant wants to do with customer make them vomit br br even a dog deserves better food then this shame on you same on your morals',
#  'good',
#  'good food',
#  'all food are partially prepared waste of money',
#  'good food and good service',
#  'quality and quantity is enough one person',
#  'good',
#  'mils no good quality very much oily food quality is not good',
#  'test good but service is not good',
#  'clining not clear',
#  'i don t like this type of food',
#  'don t like it',
#  'good',
#  'packing',
#  'rote very small saiz',
#  'super',
#  'zometo n chandan bhojnalaya chit with me',
#  'bekar khana roti was uncooked not propely cooked sara khana waste huaa and mera money bhi waste huaa i want to full refund br plastic was banned in india why this restaurant using plastics for food packaging br give me proper ans for this i ll wating for your reply',
#  'very good',
#  'rice not well cooked its seem like kachcha',
#  'good',
#  'this food may hurt our health please refund my money',
#  'or pehle to roti aati thi abhi q puri hi aati he',
#  'worsttttt',
#  'good',
#  'good',
#  'best',
#  '',
#  'very good',
#  'good food',
#  'good',
#  'class quality',
#  'not good',
#  'bad experience nd time',
#  'they didn t send cutlary and roti',
#  'make less qty and good quality food',
#  'please improve your sabzi',
#  'not good package ordered dibba thali box packing but order delivered in single single box and loose plastic bags',
#  'delevary boy is not uniform and very bad behaviour',
#  'test bakwas tha',
#  'food was okay but when i receive it it was cold but overall it is very good',
#  'good service for delivery person',
#  'burger was cold and sweet and they didn t gave ketchup disappointing',
#  'bargar thanda ho chuka tha',
#  'excellent',
#  'test of best',
#  'thanx for delevery my order',
#  'good',
#  'it s osume taste and delivery is in less time so thank you',
#  'took an hour to deliver cold burgers',
#  'sezwan ketchup is very little applied only name is sezwan burgers no sezwan test in burger',
#  'good',
#  'some vaggis',
#  'exeelent',
#  'excellent',
#  'normal berger rate high size is small',
#  'nice bro br br ok',
#  'good',
#  'bhut hi bekar sawad tha',
#  'good',
#  'delivery is so slowly',
#  'ok ok',
#  'hii',
#  'plz dhayan de pese le rahe ho to wesa bana ke bhi do',
#  'worst food',
#  'to good',
#  'received damaged food',
#  'worst experience first delivery late and second ruppes ka burger he lutere br nobody buy from ajay faltu food',
#  'not hit baav bed quality',
#  'best service and good taste',
#  'delayed and cold',
#  'good job',
#  'ketchup is less',
#  'super fantastic',
#  'super fantastic',
#  'very good service',
#  'amazing',
#  'the aize could be bigger for the price',
#  'good guy',
#  'they didn t send the sauce',
#  'let deliver',
#  'thanks u delivery in time',
#  'reasonable prices',
#  'nic br',
#  'they don t provide me spoons',
#  'good',
#  'good',
#  'goood',
#  'love d it',
#  'all is good',
#  'please send order as per mentioned in order book',
#  'both dishes delicious',
#  'thank you',
#  'late delivery',
#  'first of all the restaurant look is verry beautiful and food is verry tasty daining was verry comfortable for us servise was verry clerly done by prahlad the steward every thing is good but one lack i found from the caption verry mutch attitude and he has to be improve their way of speaking rowadey language give respect to every one this was my first time visite i love your food',
#  'delivery timing is good amp food is very swadist',
#  'nice',
#  'no trest forood on dinner br no paking good br no test br h',
#  'nice',
#  'worst service',
#  'bad test',
#  'ggooood',
#  'low quantity',
#  'very bad service',
#  'delivery boy is very good',
#  'good',
#  'very nice food',
#  'gu',
#  'very fast delivery',
#  'veg kadi is spicy',
#  'they have not provided glass for cold coffee and no spoon for eating of biryani br br very ridiculous',
#  'very nice',
#  'paner only money vest karna hai paneer ni deta sahi grevi bhar deta hai poor quality',
#  'very quick service',
#  'taste is excellent and food was hygienic but one food is always very spicy',
#  'i dont want to eat this',
#  'only gravy no manchurian',
#  'delicious',
#  'good',
#  'i need refund',
#  'anil bhai good job perfectly time',
#  'i expect better but it s okk taste is good',
#  'had a bad smell in chinese bhel',
#  'poor test not proper packing no fresh selad its poor like quality is not great perfect quality not looking good test is not good and sent without packing',
#  'some thing wrong with this dish smell like taste as a medicine water used',
#  'good',
#  'naam bade darshan chhote',
#  'good',
#  'good',
#  'nic',
#  'veg crispy to sweet amp crispy like manchurian br',
#  'good',
#  'yuuummmeeeee',
#  'excellent',
#  'service very fast',
#  'cutlery dont sent by restaurant',
#  'good food',
#  'good good',
#  'i have asked for fry noodles they told to give rs extra my bill value almost',
#  'not so good as compared',
#  'swit thi bekar',
#  'best place to devour chinese food panner recipes are top notch great service as always consistency with quality',
#  'hotelier sent an ordered food only it s a very bad blunder mistake',
#  'when eat at your place it s look and taste delicious bt whenever we made online order always it s bad taste and also not looking better',
#  'fantastic food',
#  'cabbage salad not include',
#  'took hour instead of mins approx delivery time quoted at the time of order',
#  'yume test',
#  'provided item both are luze packaging and both are not hot kindly using tin packing in future for item hot purpose many restaurants using packaging tin',
#  'very testy',
#  'zero spicy bola tha br fir bhi spicy noodles bhej diya br br',
#  'very bad experience',
#  'bekar bilkul khana no test bilkul',
#  'very good',
#  'solt over use',
#  'i am order biriyani and recived pulav',
#  'i always add cutlary in my order and i never got cutlary in my order and when call up yo the owner he said he is out of station what a horrible response to the customer',
#  'super',
#  'very bed experience',
#  'please value of our money',
#  'bakvas khana tha',
#  'no good',
#  'very fast delivery',
#  'lo koleti ka food making',
#  'very nice',
#  'too spicy and tasteless',
#  'nice thali but one vegetable bad test',
#  'food is good only the thing is some times buttermilk polythene has leakage',
#  'aise bhejna tha to menyu me kyun dusra dikhate ho',
#  'never eat stale food to call it useless the whole test is useless never ate stale food to call it useless the whole test is useless in my life i have never eaten more useless food than this',
#  'good',
#  'bekar',
#  'more spicy taste is not good waste of money not recommended to anyone',
#  'very bad missing items',
#  'i had to be admitted to the hospital because i had a bad stomach',
#  'not gullab jamun and no test',
#  'no one should eat such dirty vegetables even for free was given full water and then wasted money didn t expect this from zomato had to throw away all the food',
#  'pathetic service first late order received and secand ko salt in any paratha',
#  'thank you',
#  'good',
#  'kitna ganda khana dety ho mahek rha tha',
#  'as mentioned in instruction also again sent dal in foil bag in small quantity as complaint in last order and neither got pickle and onion in pannier combo br br',
#  'ekdam ghatia taste',
#  'cooking instructions were accepted but not considered',
#  'never order aging full waste money',
#  'fantastic',
#  'quality very poor',
#  'worst dal makhani i have ever had br it looks like sabji',
#  'nice',
#  'sari sabji basi thi rice half bowl bhi nhi tha roti bhi jali thi test bhi bekar tha fully unsatisfied with this hotel no test or very high rate',
#  'worst food',
#  'qwantity very less br packing like street food biryani',
#  'good',
#  'very bad survey',
#  'test is ok ok not best',
#  'not good worst',
#  'ghatiya thali hai br roti bhi thanda hai br sabzi bhi bakwas hai br halka halka vas bhi kar raha hai br star ke like bhi nhi hai',
#  'we order regularly from sugar n spice have been customers for a long time this was definitely not from sugar n spice it was like the food from a road side place',
#  'packing was worst and taste was not good as we go for dining in the same restuarant',
#  'very bad taste',
#  'there is a no onion and pickel inside this parsal',
#  'please serve good food',
#  'this was not from sugar n spice it was brought from somewhere else waste of our money because the taste was not of sugar n spice also no name on box nor any bill',
#  'no butter roti given br rice and hakka noodles with give onion i call after given order so why with give onion',
#  'fabulous test',
#  'good',
#  'they add milk in icecream and sell as milkshake br br rubbish',
#  'tasty',
#  'ok okay',
#  'falooda with fried noodles br no tuk mariyal in it',
#  'good',
#  'it was good i liked the taste but chocolate chips i added the quantity was less',
#  'it s yummy',
#  'parcel containers not good please use disposal cups',
#  'good delivery boy',
#  'west my money',
#  'it is not nutella',
#  'sugar is more than required',
#  'good',
#  'this is badam milk shake not good worry',
#  'do not go with this restaurant i ordered items and both are not fresh',
#  'food was nice and also delivery service was fast',
#  'bhot bekar bhai plz jo bhi bismilla shmaj k manga rha ho wo nahi mangaye iska test bhot khrab h muje to sab fek dena pada',
#  'inset of thick shake milk shake is coming',
#  'test is not more testy',
#  'wery nice fast delivered',
#  'good',
#  'very good',
#  'pura pani ho gaya tha',
#  'good',
#  'regret',
#  'roasted almond thickshake fully melted not at satisfied i want my money refund i throwed away in dustbin or else giv us credit in my next order',
#  'awesome',
#  'wow very fast delivery',
#  'average ice cream can say prefer going with the big names and get quality products rather than selecting the new ones',
#  'anhhhhh was really good btw little melted but can t blame anybody there br hey it s ice cream right',
#  'how careless',
#  'and that also very late',
#  'faluda name faltu faluda',
#  'maine jo food manga tha vah thick shake tha aur delivering milne tak vah mil se kho gaya',
#  'excellent',
#  'thank you',
#  'too much masala and the rice tasted weird',
#  'good service',
#  'these people just dont want to read the cooking instructions i clearly mentioned not to add beetroot but still they added lot of beetroot i had to throw away the food',
#  'quality and quantity is best',
#  'supar fst',
#  'pathetic sry to say but very poor quality for the price not acceptable',
#  'they didn t put spoon how do someone eat without a spoon',
#  'thank you for delivering',
#  'no quality',
#  'cooking instructions was not followed',
#  'test bekar hai',
#  'food was fantastic',
#  'nyc taste',
#  'delicious food',
#  'jala hua chicken diya',
#  'i want to just add that the delivery was a little late than expected',
#  'why are you guys not making food as per instruction',
#  'very oily',
#  'the chicken leg was so bad and stale br the taste was so dirty br br br br br br br br br br br br br br br br br br br br br br br br br br br br br br br br br br br br br br br br br br br br br br br br br br br dont give you customers like this br',
#  'bad experience',
#  'very yummy and tasty food',
#  'only agg added no chicken qty as per price',
#  'good person',
#  'very good',
#  'order was not sent properly green chicken was order in boneless but they delivered in bone very careless and bad also told to make in less oil but they also don t follow the instructions',
#  '',
#  '',
#  'hello team zomato we had order special tiranga and we received tandoori leg pice as you seen in photo we attached we want our money of specail tirnaga back as they send us wrong order please do the need full as soon as possible thank you',
#  'quantity of bheja fry is very less',
#  'smooth delivery',
#  'worest seervice',
#  'nice wow',
#  'also when i called restaurant they said bhai aap chala lo really pathetic experience',
#  'delicious',
#  'very good tats',
#  'very bad and no taste very low quantity and very high price bad experince cheap',
#  'no paper dish',
#  'nice taste',
#  'chicken me bone less jyada tha bone wala hona cahiye',
#  'lassi was missing in the order',
#  '',
#  'kadi instead of lasaniya bateka',
#  'tasty food',
#  'one item is shorted churmu is not there',
#  'taste was alright but it was too oily i am talking big oil patches floating over unappetizing and unhealthy',
#  'no onion in the parcel the ffood is very cold smell is very bad',
#  'all items were not hot it was cold next time think twice to order',
#  'the quantity of oil should be proportionate the veggies were too oily',
#  'awesome taste',
#  'very good fast delivery',
#  'good food',
#  'not good',
#  'mene gujarati thali mangvai thi just thodi der pehle ki thali and chota bachha bhi na kha paye itne kum quantity thi rice to itna kum tha ki sharm ane lagi subji me only ek chota potato ka peace tha wo bhi bharpur oil bhaio ek vinanti hai k aap log reviews dekh k hi order kare',
#  'midiyam',
#  'oily tha zyada despite instructions given while meal booking keep it less',
#  'food was very good and tasty',
#  'not tasty food',
#  'very very bed quelity food',
#  'incomplite order chass was missing and charge for it',
#  'good test appreciate',
#  'very bad taste and they gave us stale food',
#  'check karke bhejo sir',
#  'sweet missing only free sweet send',
#  'worst food tasteless and oily',
#  'good',
#  'excellent food',
#  'bekar',
#  '',
#  'great',
#  'i order food because of that offer but it was not fit to eat',
#  'taste good but garam nahi tha',
#  'don',
#  'best food',
#  'strange taste',
#  'did not follow instructions',
#  'excellent ghar jaisa taste',
#  'food is totally mess up inside the polybag how could eat such type of food',
#  'always fresh food',
#  'good food excellent taste',
#  'corns in sabji is not fresh at all',
#  'overall it was good but for dal we have asked for jain and came regularly please be careful next time',
#  'worst pannir out dated never ever visit this type of restaurant or even don t oder from there',
#  'not like the original taste of royal dine',
#  'good',
#  'uttpa pura jala huaa br sada dosa keasi se bhi nahi kata veri bad test west manny sab fakna pada pesa west',
#  'i don t like your delivery system br fore restaurant',
#  'feel like old bread',
#  'sambar me salt jyada tha aur dosa toh bohat salted bana diya not good taste',
#  'best',
#  'shambhar it was like additional salt and lime added',
#  'food was not up to mark amp also restaurant didn t sent cutlery amp delivery was also delayed so i want to give negative star amp please don t register such type of restaurant on your platform thanks',
#  'not spuan and not plat',
#  'cheat on me item are missing i need money back',
#  'not a on time delivery',
#  'bekar peking bekar food manny west',
#  'i already told that send manchurian with spoon br but resturant sens food without any spoon br br br br back my money',
#  'so bad test don t order to this restorent',
#  'i forgot the number of time i ordered from here br every time same taste and quality',
#  'mast',
#  'good and humble person',
#  'testy and healthy',
#  'the order took more than one hour to reach us',
#  'they are totaly irresponsible br how can any one eat bhaji without pav they send bhaji but not pav',
#  'i don t like this items',
#  'oder late food is bad my money back guarantee dijiye please',
#  'quantity sahi nahi he',
#  'not good taste at all it like they just did a basic pepper tadka and while eating the garlic busted in my mouth which makes me spit the food and the vegetables are raw as hell its like eating noodles with just raw veggies and pepper tadka no salt and no taste',
#  'thanks for considering my request of providing separate containers of sambhar chatni br for each dosa',
#  'good',
#  'didn t follow instructions which i gave',
#  'thanks',
#  'good taste',
#  'testy but quantity poor',
#  'gulab jamun not received',
#  'not chhachh gulab jamun not good service',
#  'no test bad quality',
#  'i ordered special deluxe from this outlet thali was good amazing service keep up the good work always guys br br br',
#  'order is not properly and quantity is very lo cutting',
#  'dal fry jeera rice must try here awesome taste delivery service very fast highly recommended to everyone',
#  'yesterday i ordered food its was yummy taste delivery service very fast food was awesome highly recommended',
#  'try kaju butter masala very good taste very good service br very tasty and hygenic food my experience was good',
#  'sabji paneer butter masala is very very yummy wonderful service excellent food with good quality nice experience br',
#  'i cant order in future from ur restaurant',
#  'there is no spoon and paper plates',
#  'the food quality very bad',
#  'very bad thali',
#  'very bad quality',
#  'is hotel me koy order mat kar na hotel wale hamko bhikhari samjhte he',
#  'ekadam bekar khana',
#  'first and worst experience',
#  'best service',
#  'west of money br totally loss food is not fresh',
#  'food is very very cold',
#  'nice',
#  'nice',
#  'third class',
#  'not packing good and not satisfied',
#  'don t order a plate with pc because you will only get instead of pc',
#  '',
#  'roti is plaan and very let dilevari',
#  'thik',
#  'khana bheja h ya mazak kiya h',
#  'paise west poor quality',
#  'br very bad quality of food in this price',
#  'food if sogy cold',
#  'mix veg subji missing roti was not it is waste of money',
#  'total waste money',
#  'food is not proper and quantity is not as per price food has not any test and some items described like papad and sweets are not given in delivery order',
#  'khane me kuch bhi thik nahi hai br khana bhi thanda hai',
#  'service not satisfied',
#  'nice',
#  'not prepared perfect order br i order extra rotti br but didn t recieved',
#  'sabji alag bheja he or aachar pickle to aaya hi nahi he test everage packing are without beg only dish hand over',
#  'paking ke sath beg bhai hona chahiye',
#  'isse bakvas thaali hamne aaj tak nahi khaee dal aur sabji baasi mili',
#  'found plastic thread in the food br very poor hygiene',
#  'br packing so bad plz proper packing',
#  'very good',
#  'bad taste',
#  'not bad',
#  'but delivery is very let',
#  'nice taste',
#  'only rice in it small pices chiken only no meaning of chiken biryani',
#  'ab pehle se bahot hi low quantity aa rahi hai',
#  'good',
#  'not proper packing of food br gravy material is send in this type of packing',
#  'my everytime service please his man',
#  'no chicken in chicken rice',
#  'chicken biryani quality need improvement',
#  'instructions me likha tha without gravy uske bad bi gravy bhej diya',
#  'not good',
#  'zomato delivery is not satisfied order is ready but zomato man is not there at time',
#  'verey nice food',
#  'please provide fresh amp hygiene foods',
#  'nice',
#  'good br',
#  'packing was not at all good br all oil spread on other items n my meal was spoiled',
#  'little more improvement',
#  'all order leakage form container',
#  'actually what i ordered and what i got both is different i ate many times in same dish same restaurant ruin my evening',
#  'this time food is very bad ni tesh also chicken pics is not good after eat very bad semll in this food test also bed so not very happy this service and food quality',
#  'quality of food',
#  'masala papad ka packet rs ka hota hai aur aap ek papad ka dete ho',
#  'rude behaviour',
#  'it was totally different from what i ve order',
#  'good food',
#  'waste of money',
#  'terrible experience there was nail in the roti the photo is attached next to the bolus',
#  'no onion or chutney send my with order',
#  'very bad packaging',
#  'every time food quality is good but this time i think it s very salty both starters are not estable',
#  'fine',
#  'dabe me se oli nikla tha or maf kr naa acha tha baki sab me problem hi hai chaval me namak nhi tha or roti aachi trha se paki nhi thi aaj peli bar muje order me mza nhi aaya khana let aaya or ye sab thik nhi lga',
#  'mast',
#  'make it more spicy',
#  'good',
#  'covenity problem also test',
#  'the delivery boy forget the place i marked and goes wrong way but biryani taste and his before time come on that area that i like what ever he get wrong turn but taste is awesome',
#  'good service',
#  'not good',
#  'nice chicken biryani recipe so happy',
#  'very nice',
#  'taste is not good and instead of tikka biryani normal biryani had come',
#  'mast',
#  'bakwash biryani thi yaha se kabhi mat mangana',
#  'i got found stone inside the package very bed experience',
#  'wong recommend',
#  'nice',
#  'on time',
#  'biryani me bal nikal rahe h bahut h ghatiya saf safai bilkun nahi h',
#  'all taste same',
#  'very very nice',
#  'super test',
#  'nice',
#  'ok ok',
#  'nice',
#  'tasty biryani',
#  'nice',
#  'mint after needs to biryani',
#  'bad food',
#  'good',
#  'good',
#  'filled with plain rice',
#  'not a good test',
#  'best of luck',
#  'great',
#  'delivery service is very fast and delivery boy is good in behaviour',
#  'it is not a biriyani pathetic taste',
#  'that s cheating i m ordering chicken biryani hi was send me paneer biryani',
#  'good behaviour',
#  'very good behave and timely reach at location',
#  'exalnt',
#  'best biryani ever go for it taste is soo good enjoy',
#  'good',
#  'did not receive the peri peri fries with frankie even after paying for both of them',
#  'it s good but not same taste compared to last ordered',
#  'make it a little soft',
#  'it was not what i order it was something different frankie s needs improvement never order from zomato other delivery apps are better br sorry regards',
#  'i order diffrent test frankie total order br restaurant send all food in same packing without any tag all mixed up and and not found without having test also used plastick silver chief paper used',
#  'worst food ever',
#  'it s not same which i ordered its full of test less poteto and too much mayonnaise insted of cheess',
#  'i order this often but this time it did not taste the usual',
#  'i ordered frankies but none was labelled hassel to identify which one was which otherwise food was good',
#  'never going to order from here as this the order i got was not that i ordered',
#  'jain kese pata chalengea',
#  'i ordered franky but i only get one',
#  'it s stale food taste is very bad',
#  'very bad',
#  'hope no paneer amp cheese extra add',
#  'amazing br',
#  'we needs delivery man like him',
#  'perfect',
#  'amazing',
#  'the packaging has to be appropriate',
#  'no more cheese nd no test',
#  'yes we wait for long to get good tasty good for our hunger but this is not what we deserve after paying good amount',
#  'tha packeging was nt proper the frankie was nt properly packed and cnt be easily eat all the stuff was coming out',
#  'no taste',
#  'pahle jaisa taste nahi tha and crspy nahi tha br packing not good',
#  'awesome will repeat again in future',
#  'empty frankie no materials inside',
#  'very bad',
#  'highly unsetisfectry uncooked and unbeatable food never going to try again',
#  'bad food',
#  'the frankie was not tasty the vegetables used did not seemed fresh',
#  'i have told the instructions then also not follow',
#  'testy ynmm',
#  'vry bad',
#  'very bad it was not special it was jst chinese franky ntng special',
#  'bakwas test',
#  'worst food test lesss wala paisa waisted he bhi koi magana matt yaha se ghatiya hain khud test kr ke bol rha hun bohot hi jyada worsted test hain',
#  'manchurian cheeze ki jagah paneer cheeze frankie deliver aai he br bahot bekar thi frankie',
#  'thank you faster dilevary',
#  'pls don t delay in delivery',
#  'take this back',
#  'nice',
#  'i ve always enjoyed this combo being a foodie this combo never disappoints me it costs around rupees including delivery taxes and doesn t disappoint at all the quantity and taste is such a delight',
#  'very bad test no value of money br only two peace in chicken laziz handi',
#  'good',
#  'nice service',
#  'very poor quantity',
#  'masala kam tha',
#  'hopeless taste never order again',
#  'roti main se dhaga thread nikala dhyan se br br aaj ki roti bhi barabar nahj thi aisa laga dusri kahi jagah se bana ke bheji hau total disappointment',
#  'delivery was soo late it have taken almost min for delivery',
#  'i placed the order for butter roti and i got chappathi not fair',
#  'the item i recieved was not laziz handi i don t know what it was but was of very poor quality first time i had this bad experience',
#  '',
#  'happy',
#  'want refund',
#  'authentic chicken biryani taste you have in this hyderabadi chicken dum biryani recipe delhi dastarkhwan i always order biryani only from you because of that original aroma and taste i really appreciated',
#  'hopeless',
#  'worst graby ever',
#  'worst taste ever',
#  'very delicious but too spicy',
#  'worst restaurant i have ever seen i received cockroach in biryani',
#  'very nice',
#  'na biryani wala color hai na biryani wali khushbu sale ne chawal ubaalkar bhej diya aur band karte hotel',
#  'very bad',
#  'very bed',
#  'its not taste like fried rice',
#  'briyani me masala kam tha',
#  'to late delivery',
#  'it can not be called biryani it was just rice tasteless and chicken pieces blend br pathetic taste and worst biryani i ever had',
#  'worst roti',
#  'yummy',
#  'the food wasn t worth more than rupees',
#  'tasty is awesome',
#  'specially requested for green chutney but not received it s every time happening',
#  'food was not as per taste it wasn t tasty chap was not cooked properly',
#  'it was my bad expernce',
#  'nice',
#  'worst people at restaurants',
#  'only oil floating even no onion given',
#  'taste was good but portion was less',
#  'authentic test',
#  'bekr khana',
#  'the quality was not as good as before',
#  'quantity is low',
#  'uncooked and salty food',
#  'increase portion of sabji',
#  'bad preparing',
#  'very rough behavior of restaurant staff on phone',
#  'good',
#  'items were missing and refund amount was not equal to order',
#  '',
#  'no garlic in cheese garlic nan',
#  'pl refund my dal fry rupees',
#  'surb teste',
#  'quantity is also not appropriate to serve person and rirce dal bhth are verymuch undercooked',
#  'supplied two mix veg paratha',
#  'good',
#  'full thali me jira rice dal fry to tahi nahi',
#  'great food',
#  'best dal makhani',
#  'nice job and behaviour',
#  'i have ordered paneer cheese paratha and there is no cheese added completely disappointed very bad management and horrible experience',
#  'delivery boy was good',
#  'taste is good but portion is too less',
#  'munchuriyan is very cold and roti is very cold not happy',
#  'paratha is not well coked',
#  'not proper food packing delievery br plz seen proper food packaging any order',
#  'test is superb but salad is not received need salad',
#  'super',
#  'have order dhosa only received dhosa poor service',
#  'food is not pack properly',
#  'no salad maisoor quantity is too less',
#  'low quantity',
#  'item sada dhosa want delivered or quantity was less',
#  'good job',
#  'good job',
#  'thik hai',
#  'excellent',
#  'your app pic and practical product very wrong your parsaul not ok',
#  'taste is good but sells the items way more costly than offline',
#  'fast delivery boy bullet boy',
#  'good cooking real food and very good restaurant in very very very good',
#  'very bad service',
#  'pls don t order any food malhar dhosa totally waste of money and time',
#  'delivery boy not us zometo t shirt',
#  'awesome',
#  'good',
#  'very bed service next time no any order on malhar',
#  'good service',
#  'half quantity of extra paper delivered never order',
#  'paper is not good',
#  '',
#  'product quantity is less with compare to price and mentioned instructions was not followed',
#  'it was very very tasty but not satisfactory for person',
#  'improve portion size taste is good n provide more chutney n sambhar',
#  'rhoda taste is delicious and br good and packaging is very good',
#  'pleaseeee put more chutney and sambar in next order',
#  'sambhar is sweet with dosa sambhar must be little sour',
#  'so tasty in malhar dosa it s food are so spicy and very good and serves so aap cool and are special le dosa has the very tasty and mysore dosa has the so yummies',
#  'not good we ordered paneer dosa br we mentioned extra daal amp chutney but not provided even salt was less so this time malhar was not up to matk',
#  'good restaurant if you find the restaurant for dhosa chhose with restaurant quality as well test is also good restaurant owner attitude is very nice provide a gudiline of food',
#  'we went over this place to have surati styled dosa they have a decent seating space which is neat n clean and hygienic br br ordered two flavours of dosas br br mysore masala dosa it tastes so good that we ordered it twice so authentic indian spices flavours and very crisp dosa br br gini roll dosa it was lil bit spring roll style stuffing with a mix taste of bhaaji and pizza toppings good in flavours and crispiness br br they serve dosas with unlimited offering of sambhar coconut chatni and onion amp tomato mix salad br the add on to this place is their in house prepared mouth freshener mukhwaas sweet and salty at the same time br br looking forward to visit this place with family',
#  'they have unique flavours of dosa especially a corn one we ordered it and it was very tasty worth trying br family place with tasty food and ambience is not much but food is good',
#  'very nice n very tasty',
#  'bekar',
#  'amazing',
#  'average',
#  'worst ever taste',
#  'cold rice served',
#  'veree good',
#  'very nice test',
#  'good',
#  'nice',
#  'sab meetha h',
#  '',
#  'sambhal very cold',
#  'nice',
#  'good',
#  'good',
#  'good',
#  'quantity is lesses then expected',
#  'good',
#  'nice',
#  'good',
#  'mane dhaniya nathi bhavta atle',
#  'good',
#  'everything is like testy so thanks brother',
#  'nice',
#  'good',
#  'gud service',
#  'i want my money back and also do collect your food i am not going to eat this',
#  'good',
#  'thank you',
#  'thard class',
#  'bad br',
#  'top',
#  'too spicy',
#  'good',
#  'there is no pickle with paratha',
#  'khub sars',
#  'nice',
#  'good',
#  'fast delivery',
#  'good product',
#  'good',
#  'speed',
#  'best quality',
#  'cheated in coupon offer didn t gave',
#  'good job',
#  'very good',
#  'very testy',
#  'test not good',
#  'delevery boy behaviour very rude and not a good delivery boy so i suggest next time my order he boy delivery my food',
#  'it can not send full order',
#  'dealy delivery',
#  'good food',
#  'very bad experience with radhe restuarant',
#  'food was not hot enough',
#  'quantity is not gram',
#  'too bad',
#  'supreb delivery men osm',
#  'restaurant does not follow the instructions',
#  'very good fob bro',
#  'very nice',
#  'tya jamvi aevu parsal nthi aavtu',
#  'good food',
#  'very nice',
#  'long time',
#  '',
#  'thik he ji',
#  'bad timing',
#  'very good service',
#  've good',
#  'all good',
#  'i sent to msg for the add salad in my order but resturant are not send me salad any package',
#  'bvui kharb bali ghyu hatu',
#  ...]
